# %% [markdown]
# # Verrific Quick Demo
#
# This notebook shows how to:
# 0. Get a TEI XML file from a PDF
# 1. Load references from an existing Grobid TEI XML file.
# 2. (Optionally) Enrich them using a running **biblio-glutton** service.
# 3. View a concise summary table of extracted vs. matched references.

# %% [markdown]
# ## Setup
# Run Grobid on a PDF file to get a TEI XML file.

# %%
# Imports & path setup
from verrific.core import Verrific
import pandas as pd
from pathlib import Path

# process a PDF file by GROBID
Verrific.process_pdf_dir(Path('/Users/jakub/dev/verrific/pdf'))

tei_path = Path('/Users/jakub/dev/verrific/tei/2012-an-open-large-scale-collaborative-effort-to-estimate-the-reproducibility-of-psychological-science.grobid.tei.xml')
assert tei_path.exists(), f'TEI file not found: {tei_path}'
tei_path
# Out:
# INFO - Loading configuration file from /Users/jakub/dev/verrific/.config.json
# 2025-09-09 11:03:47,757 - grobid_client.grobid_client.config_loader - INFO - Loading configuration file from /Users/jakub/dev/verrific/.config.json
# INFO - Configuration file loaded successfully
# 2025-09-09 11:03:47,761 - grobid_client.grobid_client.config_loader - INFO - Configuration file loaded successfully
# 2025-09-09 11:03:47,763 - grobid_client.grobid_client - INFO - Logging configured - Level: INFO, Console: True, File: disabled
# 2025-09-09 11:03:47,926 - grobid_client.grobid_client - INFO - GROBID server http://devserver:8070 is up and running
# 2025-09-09 11:03:47,927 - grobid_client.grobid_client - INFO - Found 1 file(s) to process
# 2025-09-09 11:03:51,694 - grobid_client.grobid_client - INFO - Processing completed: 1 out of 1 files processed
# PosixPath('/Users/jakub/dev/verrific/tei/2012-an-open-large-scale-collaborative-effort-to-estimate-the-reproducibility-of-psychological-science.grobid.tei.xml')

# %% [markdown]
# ## 1. Parse TEI into structured references

# %%
v = Verrific.from_grobid_tei(tei_path)
print(f'Extracted {len(v.references)} references.')
# Peek at the first 3 references (raw truncated)
print('First 3 extracted references (raw):\n')
for r in v.references[:3]:
    print('- DOI:', r.doi, '| First Author:', r.first_author_surname, '\n  Title:', (r.title[:80] + '...') if r.title and len(r.title) > 80 else r.title)
# Out:
# Extracted 21 references.
# First 3 extracted references (raw):
#
# - DOI: None | First Author: Bacon
#   Title: Fr. Rogeri Bacon Opera quaedam hactenus inedita
# - DOI: 10.1038/483531a | First Author: Begley
#   Title: Raise standards for preclinical cancer research
# - DOI: 10.1177/1745691611429353 | First Author: Bertamini
#   Title: Bite-size science and its undesired side effects

# %% [markdown]
# ## 2. (Optional) Enrich via biblio-glutton

# %%
# You can skip this cell if you don't have biblio-glutton running.
BASE_URL = 'http://devserver:8080'  # Change if needed (e.g., 'http://localhost:8080')
try:
    await v.enrich_with_biblio_glutton(base_url=BASE_URL)
    print('Enrichment complete.')
except Exception as e:
    print('Enrichment skipped / failed:', e)
# Out:
# Enrichment complete.

# %% [markdown]
# ## 3. Summary table
# A checkmark indicates a successful enrichment (HTTP 200 with JSON) and absence of an error marker.

# %%
summary_df = v.summary()
summary_df
# Out:
#                                  DOI  \
# 0
# 1                    10.1038/483531a
# 2           10.1177/1745691611429353
# 3
# 4
# 5                   10.1037/h0076157
# 6           10.3389/fncom.2012.00008
# 7       10.1371/journal.pmed.0020124
# 8     10.1126/sci-ence.334.6060.1225
# 9           10.1177/0956797611430953
# 10
# 11                  10.1037/a0025172
# 12
# 13
# 14                10.1038/nrd3439-c1
# 15     10.1016/S0149-2063_03_00024-2
# 16
# 17                  10.1037/a0015108
# 18          10.1177/0956797611417632
# 19         10.1007/s11121-011-0217-6
# 20  10.1016/j.neuroimage.2008.10.061
#
#                                                 Title First Author Surname  \
# 0     Fr. Rogeri Bacon Opera quaedam hactenus inedita                Bacon
# 1     Raise standards for preclinical cancer research               Begley
# 2    Bite-size science and its undesired side effects            Bertamini
# 3   ESP and psychokinesis. A philosophical examina...               Braude
# 4                                      Changing order              Collins
# 5   Consequences of prejudice against the null hyp...            Greenwald
# 6   Tracking replicability as a method of post-pub...           Hartshorne
# 7      Why most published research findings are false            Ioannidis
# 8                         Again, and again, and again                Jasny
# 9   Measuring the prevalence of questionable resea...                 John
# 10            The structure of scientific revolutions                 Kuhn
# 11  Fearing the future of empirical psychology: Be...                Lebel
# 12  Scientific utopia: II. Restructuring incentive...                Nosek
# 13                  The logic of scientific discovery               Popper
# 14  Believe it or not: How much can we rely on pub...                Prinz
# 15          Replication in advertising research: 1977                 Reid
# 16                 Replication in behavioral research            Rosenthal
# 17  Shall we really do it again? The powerful conc...              Schmidt
# 18  Falsepositive psychology: Undisclosed flexibil...              Simmons
# 19                  Replication in prevention science            Valentine
# 20  Evaluating the consistency and specificity of ...                Wager
#
#                                                   Raw Matched
# 0   Bacon, R. (1859). Fr. Rogeri Bacon Opera quaed...       ✅
# 1   Begley, C. G., & Ellis, L. M. (2012). Raise st...       ✅
# 2   Bertamini, M., & Munafò, M. R. (2012). Bite-si...       ✅
# 3   Braude, S. E. (1979). ESP and psychokinesis. A...       ✅
# 4   Collins, H. M. (1985). Changing order. London,...       ✅
# 5   Greenwald, A. G. (1975). Consequences of preju...       ✅
# 6   Hartshorne, J. K., & Schachner, A. (2012). Tra...       ✅
# 7   Ioannidis, J. P. A. (2005). Why most published...       ✅
# 8   Jasny, B. R., Chin, G., Chong, L., & Vignieri,...      ⚠️
# 9   John, L., Loewenstein, G., & Prelec, D. (2012)...       ✅
# 10  Kuhn, T. S. (1962). The structure of scientifi...       ✅
# 11  LeBel, E. P., & Peters, K. R. (2011). Fearing ...       ✅
# 12  Nosek, B. A., Spies, J. R., & Motyl, M. (2012)...       ✅
# 13  Popper, K. (1992). The logic of scientific dis...       ✅
# 14  Prinz, F., Schlange, T., & Asadullah, K. (2011...       ✅
# 15  Reid, L. N., Soley, L. C., & Wimmer, R. D. (19...       ✅
# 16  Rosenthal, R. (1991). Replication in behaviora...       ✅
# 17  Schmidt, S. (2009). Shall we really do it agai...       ✅
# 18  Simmons, J. P., Nelson, L. D., & Simonsohn, U....       ✅
# 19  Valentine, J. C., Biglan, A., Boruch, R. F., C...       ✅
# 20  Wager, T. D., Lindquist, M. A., Nichols, T. E....       ✅

# %%
for r in v.references[:3]:
    # show only enriched fields
    print(r.glutton)
# Out:
# {'DOI': '10.1017/cbo9781139162791', 'ISBN': ['9781139162791', '9781108042451'], 'URL': 'https://doi.org/10.1017/cbo9781139162791', 'author': [{'affiliation': [], 'family': 'Bacon', 'given': 'Roger', 'sequence': 'first'}], 'content-domain': {'crossmark-restriction': False, 'domain': []}, 'created': {'date-parts': [[2013, 8, 5]], 'date-time': '2013-08-05T04:55:15Z', 'timestamp': 1375678515000}, 'deposited': {'date-parts': [[2022, 10, 15]], 'date-time': '2022-10-15T02:32:58Z', 'timestamp': 1665801178000}, 'edition-number': '1', 'editor': [{'affiliation': [], 'family': 'Brewer', 'given': 'J. S.', 'sequence': 'additional'}], 'is-referenced-by-count': 1, 'isbn-type': [{'type': 'electronic', 'value': '9781139162791'}, {'type': 'print', 'value': '9781108042451'}], 'issued': {'date-parts': [[2012, 11, 15]]}, 'license': [{'URL': 'https://www.cambridge.org/core/terms', 'content-version': 'unspecified', 'delay-in-days': 263, 'start': {'date-parts': [[2013, 8, 5]], 'date-time': '2013-08-05T00:00:00Z', 'timestamp': 1375660800000}}], 'member': '56', 'prefix': '10.1017', 'published': {'date-parts': [[2012, 11, 15]]}, 'published-online': {'date-parts': [[2013, 8, 5]]}, 'published-print': {'date-parts': [[2012, 11, 15]]}, 'publisher': 'Cambridge University Press', 'reference-count': 0, 'references-count': 0, 'resource': {'primary': {'URL': 'https://www.cambridge.org/core/product/identifier/9781139162791/type/book'}}, 'score': 0.0, 'source': 'Crossref', 'title': ['Fr. Rogeri Bacon Opera quædam hactenus inedita'], 'type': 'book'}
# {'DOI': '10.1038/483531a', 'ISSN': ['0028-0836', '1476-4687'], 'URL': 'https://doi.org/10.1038/483531a', 'alternative-id': ['BF483531a'], 'assertion': [{'group': {'label': 'Article History', 'name': 'ArticleHistory'}, 'label': 'First Online', 'name': 'first_online', 'order': 1, 'value': '28 March 2012'}, {'label': 'Free to read', 'name': 'free', 'value': 'This content has been made available to all.'}], 'author': [{'affiliation': [], 'family': 'Begley', 'given': 'C. Glenn', 'sequence': 'first'}, {'affiliation': [], 'family': 'Ellis', 'given': 'Lee M.', 'sequence': 'additional'}], 'container-title': ['Nature'], 'content-domain': {'crossmark-restriction': False, 'domain': ['link.springer.com']}, 'created': {'date-parts': [[2012, 3, 27]], 'date-time': '2012-03-27T14:44:54Z', 'timestamp': 1332859494000}, 'deposited': {'date-parts': [[2023, 5, 18]], 'date-time': '2023-05-18T01:56:48Z', 'timestamp': 1684375008000}, 'is-referenced-by-count': 2196, 'issn-type': [{'type': 'print', 'value': '0028-0836'}, {'type': 'electronic', 'value': '1476-4687'}], 'issue': '7391', 'issued': {'date-parts': [[2012, 3, 28]]}, 'journal-issue': {'issue': '7391', 'published-print': {'date-parts': [[2012, 3, 29]]}}, 'language': 'en', 'license': [{'URL': 'http://www.springer.com/tdm', 'content-version': 'tdm', 'delay-in-days': 0, 'start': {'date-parts': [[2012, 3, 28]], 'date-time': '2012-03-28T00:00:00Z', 'timestamp': 1332892800000}}, {'URL': 'http://www.springer.com/tdm', 'content-version': 'vor', 'delay-in-days': 0, 'start': {'date-parts': [[2012, 3, 28]], 'date-time': '2012-03-28T00:00:00Z', 'timestamp': 1332892800000}}], 'link': [{'URL': 'http://www.nature.com/articles/483531a.pdf', 'content-type': 'application/pdf', 'content-version': 'vor', 'intended-application': 'text-mining'}, {'URL': 'http://www.nature.com/articles/483531a', 'content-type': 'text/html', 'content-version': 'vor', 'intended-application': 'text-mining'}, {'URL': 'http://www.nature.com/articles/483531a.pdf', 'content-type': 'application/pdf', 'content-version': 'vor', 'intended-application': 'similarity-checking'}], 'member': '297', 'page': '531-533', 'prefix': '10.1038', 'published': {'date-parts': [[2012, 3, 28]]}, 'published-online': {'date-parts': [[2012, 3, 28]]}, 'published-print': {'date-parts': [[2012, 3, 29]]}, 'publisher': 'Springer Science and Business Media LLC', 'reference-count': 5, 'references-count': 5, 'relation': {'has-review': [{'asserted-by': 'object', 'id': '10.3410/f.717248112.792503067', 'id-type': 'doi'}]}, 'resource': {'primary': {'URL': 'https://www.nature.com/articles/483531a'}}, 'score': 0.0, 'short-container-title': ['Nature'], 'source': 'Crossref', 'title': ['Raise standards for preclinical cancer research'], 'type': 'journal-article', 'update-policy': 'https://doi.org/10.1007/springer_crossmark_policy', 'updated-by': [{'DOI': '10.1038/485041e', 'label': 'Correction', 'source': 'publisher', 'type': 'correction', 'updated': {'date-parts': [[2012, 5, 2]], 'date-time': '2012-05-02T00:00:00Z', 'timestamp': 1335916800000}}], 'volume': '483'}
# {'DOI': '10.1177/1745691611429353', 'ISSN': ['1745-6916', '1745-6924'], 'URL': 'https://doi.org/10.1177/1745691611429353', 'alternative-id': ['10.1177/1745691611429353'], 'author': [{'affiliation': [{'name': 'University of Liverpool'}], 'family': 'Bertamini', 'given': 'Marco', 'sequence': 'first'}, {'affiliation': [{'name': 'University of Bristol'}], 'family': 'Munafò', 'given': 'Marcus R.', 'sequence': 'additional'}], 'container-title': ['Perspectives on Psychological Science'], 'content-domain': {'crossmark-restriction': True, 'domain': ['journals.sagepub.com']}, 'created': {'date-parts': [[2012, 1, 6]], 'date-time': '2012-01-06T22:15:31Z', 'timestamp': 1325888131000}, 'deposited': {'date-parts': [[2025, 1, 28]], 'date-time': '2025-01-28T14:19:46Z', 'timestamp': 1738073986000}, 'is-referenced-by-count': 44, 'issn-type': [{'type': 'print', 'value': '1745-6916'}, {'type': 'electronic', 'value': '1745-6924'}], 'issue': '1', 'issued': {'date-parts': [[2012, 1]]}, 'journal-issue': {'issue': '1', 'published-print': {'date-parts': [[2012, 1]]}}, 'language': 'en', 'license': [{'URL': 'https://journals.sagepub.com/page/policies/text-and-data-mining-license', 'content-version': 'tdm', 'delay-in-days': 0, 'start': {'date-parts': [[2012, 1, 1]], 'date-time': '2012-01-01T00:00:00Z', 'timestamp': 1325376000000}}], 'link': [{'URL': 'https://journals.sagepub.com/doi/pdf/10.1177/1745691611429353', 'content-type': 'application/pdf', 'content-version': 'vor', 'intended-application': 'text-mining'}, {'URL': 'https://journals.sagepub.com/doi/full-xml/10.1177/1745691611429353', 'content-type': 'application/xml', 'content-version': 'vor', 'intended-application': 'text-mining'}, {'URL': 'https://journals.sagepub.com/doi/pdf/10.1177/1745691611429353', 'content-type': 'unspecified', 'content-version': 'vor', 'intended-application': 'similarity-checking'}], 'member': '179', 'page': '67-71', 'prefix': '10.1177', 'published': {'date-parts': [[2012, 1]]}, 'published-online': {'date-parts': [[2012, 1, 5]]}, 'published-print': {'date-parts': [[2012, 1]]}, 'publisher': 'SAGE Publications', 'reference-count': 24, 'references-count': 24, 'resource': {'primary': {'URL': 'https://journals.sagepub.com/doi/10.1177/1745691611429353'}}, 'score': 0.0, 'short-container-title': ['Perspect Psychol Sci'], 'source': 'Crossref', 'title': ['Bite-Size Science and Its Undesired Side Effects'], 'type': 'journal-article', 'update-policy': 'https://doi.org/10.1177/sage-journals-update-policy', 'volume': '7'}
